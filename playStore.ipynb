# %% [markdown]
# <a href="https://colab.research.google.com/github/malakbayramovaa/pandas-tutorials/blob/main/playStore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/googleplaystore.csv')
data.head(15)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
data['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
data['Price'].value_counts()
# Out:
# Price
# 0           10040
# $0.99         148
# $2.99         129
# $1.99          73
# $4.99          72
#             ...
# $394.99         1
# $1.26           1
# Everyone        1
# $1.20           1
# $1.04           1
# Name: count, Length: 93, dtype: int64

# %%
import numpy as np

# %%
data['Price']=data['Price'].str.replace('$', '', regex=False).replace('Everyone', np.nan).astype('float')

# %%
data['Price'].value_counts()
# Out:
# Price
# 0.00      10040
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
#           ...
# 3.61          1
# 394.99        1
# 1.26          1
# 1.20          1
# 1.04          1
# Name: count, Length: 92, dtype: int64

# %%
data['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,    nan,   1.2 ,   1.04])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.describe()
# Out:
#             Rating         Price
# count  9367.000000  10840.000000
# mean      4.193338      1.027368
# std       0.537431     15.949703
# min       1.000000      0.000000
# 25%       4.000000      0.000000
# 50%       4.300000      0.000000
# 75%       4.500000      0.000000
# max      19.000000    400.000000

# %%
data['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
data['Rating']=data['Rating'].replace(19. , data['Rating'].mean())

# %%
data['Rating'].unique()
# Out:
# array([4.1       , 3.9       , 4.7       , 4.5       , 4.3       ,
#        4.4       , 3.8       , 4.2       , 4.6       , 3.2       ,
#        4.        ,        nan, 4.8       , 4.9       , 3.6       ,
#        3.7       , 3.3       , 3.4       , 3.5       , 3.1       ,
#        5.        , 2.6       , 3.        , 1.9       , 2.5       ,
#        2.8       , 2.7       , 1.        , 2.9       , 2.3       ,
#        2.2       , 1.7       , 2.        , 1.8       , 2.4       ,
#        1.6       , 2.1       , 1.4       , 1.5       , 1.2       ,
#        4.19333832])

# %%
data['Rating'].describe()
# Out:
# count    9367.000000
# mean        4.191758
# std         0.515191
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159   19M      10,000+  Free    0.0       Everyone
# 1     967   14M     500,000+  Free    0.0       Everyone
# 2   87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644   25M  50,000,000+  Free    0.0           Teen
# 4     967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data['Last Updated']=pd.to_datetime(data['Last Updated'], errors='coerce', format='mixed')

# %%
data['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10841, dtype: datetime64[ns]

# %%
data['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
data['Size']=data['Size'].str.replace('M', '').str.replace('k', '').str.replace('+', '')

# %%
data['Size'].unique()
# Out:
# array(['19', '14', '8.7', '25', '2.8', '5.6', '29', '33', '3.1', '28',
#        '12', '20', '21', '37', '2.7', '5.5', '17', '39', '31', '4.2',
#        '7.0', '23', '6.0', '6.1', '4.6', '9.2', '5.2', '11', '24',
#        'Varies with device', '9.4', '15', '10', '1.2', '26', '8.0', '7.9',
#        '56', '57', '35', '54', '201', '3.6', '5.7', '8.6', '2.4', '27',
#        '2.5', '16', '3.4', '8.9', '3.9', '2.9', '38', '32', '5.4', '18',
#        '1.1', '2.2', '4.5', '9.8', '52', '9.0', '6.7', '30', '2.6', '7.1',
#        '3.7', '22', '7.4', '6.4', '3.2', '8.2', '9.9', '4.9', '9.5',
#        '5.0', '5.9', '13', '73', '6.8', '3.5', '4.0', '2.3', '7.2', '2.1',
#        '42', '7.3', '9.1', '55', '6.5', '1.5', '7.5', '51', '41', '48',
#        '8.5', '46', '8.3', '4.3', '4.7', '3.3', '40', '7.8', '8.8', '6.6',
#        '5.1', '61', '66', '79', '8.4', '118', '44', '695', '1.6', '6.2',
#        '53', '1.4', '3.0', '5.8', '3.8', '9.6', '45', '63', '49', '77',
# ...

# %%
data['Size']=data['Size'].replace('Varies with device', np.nan)

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                   object
# Size                      object
# Installs                  object
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %%
data['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %%
data.head(15)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews Size     Installs  Type  Price Content Rating  \
# 0     159   19      10,000+  Free    0.0       Everyone
# 1     967   14     500,000+  Free    0.0       Everyone
# 2   87510  8.7   5,000,000+  Free    0.0       Everyone
# 3  215644   25  50,000,000+  Free    0.0           Teen
# 4     967  2.8     100,000+  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
data['Category']=data['Category'].str.replace('_', ' ').str.replace('AND', '&')

# %%
data['Category']=data['Category'].str.lower()

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data.head()
# Out:
#                                                  App      Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  art & design     4.1
# 1                                Coloring book moana  art & design     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  art & design     4.7
# 3                              Sketch - Draw & Paint  art & design     4.5
# 4              Pixel Draw - Number Art Coloring Book  art & design     4.3
#
#   Reviews Size     Installs  Type  Price Content Rating  \
# 0     159   19      10,000+  Free    0.0       Everyone
# 1     967   14     500,000+  Free    0.0       Everyone
# 2   87510  8.7   5,000,000+  Free    0.0       Everyone
# 3  215644   25  50,000,000+  Free    0.0           Teen
# 4     967  2.8     100,000+  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
data['Reviews']=pd.to_numeric(data['Reviews'], errors='coerce')

# %%
data['Size']=pd.to_numeric(data['Size'], errors='coerce')

# %%
data.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                  float64
# Size                     float64
# Installs                  object
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %%
categoric_cols=data.select_dtypes(include='object')
numeric_cols=data.select_dtypes(include=np.number)

# %%
categoric_cols
# Out:
#                                                      App           Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       art & design
# 1                                    Coloring book moana       art & design
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       art & design
# 3                                  Sketch - Draw & Paint       art & design
# 4                  Pixel Draw - Number Art Coloring Book       art & design
# ...                                                  ...                ...
# 10836                                   Sya9a Maroc - FR             family
# 10837                   Fr. Mike Schmitz Audio Teachings             family
# 10838                             Parkinson Exercices FR            medical
# 10839                      The SCP Foundation DB fr nn5n  books & reference
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology          lifestyle
#
# ...

# %%
numeric_cols
# Out:
#        Rating   Reviews  Size  Price
# 0         4.1     159.0  19.0    0.0
# 1         3.9     967.0  14.0    0.0
# 2         4.7   87510.0   8.7    0.0
# 3         4.5  215644.0  25.0    0.0
# 4         4.3     967.0   2.8    0.0
# ...       ...       ...   ...    ...
# 10836     4.5      38.0  53.0    0.0
# 10837     5.0       4.0   3.6    0.0
# 10838     NaN       3.0   9.5    0.0
# 10839     4.5     114.0   NaN    0.0
# 10840     4.5  398307.0  19.0    0.0
#
# [10841 rows x 4 columns]

# %%
data['Reviews'].unique()
# Out:
# array([1.59000e+02, 9.67000e+02, 8.75100e+04, ..., 6.03000e+02,
#        1.19500e+03, 3.98307e+05])

# %%
data['Installs'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Installs'].describe()
# Out:
# count          10841
# unique            22
# top       1,000,000+
# freq            1579
# Name: Installs, dtype: object

# %%
for col in categoric_cols:
  data[col]=data[col].fillna(data[col].mode()[0])

# %%
for col in numeric_cols:
  data[col]=data[col].fillna(data[col].mean())

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      1
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
data['Last Updated']=data['Last Updated'].fillna(method='bfill')
# Out:
# /tmp/ipython-input-2034855380.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Last Updated']=data['Last Updated'].fillna(method='bfill')

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
data.head(15)
# Out:
#                                                   App      Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  art & design     4.1
# 1                                 Coloring book moana  art & design     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  art & design     4.7
# 3                               Sketch - Draw & Paint  art & design     4.5
# 4               Pixel Draw - Number Art Coloring Book  art & design     4.3
# 5                          Paper flowers instructions  art & design     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  art & design     3.8
# 7                                    Infinite Painter  art & design     4.1
# 8                                Garden Coloring Book  art & design     4.4
# 9                       Kids Paint Free - Drawing Fun  art & design     4.7
# 10                            Text on Photo - Fonteee  art & design     4.4
# ...

# %%
data['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8715
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
data['Type'].value_counts()
# Out:
# Type
# Free    10040
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
data['Category'].value_counts().sort_values(ascending=False)
# Out:
# Category
# family               1972
# game                 1144
# tools                 843
# medical               463
# business              460
# productivity          424
# personalization       392
# communication         387
# sports                384
# lifestyle             382
# finance               366
# health & fitness      341
# photography           335
# social                295
# news & magazines      283
# shopping              260
# travel & local        258
# dating                234
# books & reference     231
# video players         175
# education             156
# entertainment         149
# maps & navigation     137
# food & drink          127
# house & home           88
# auto & vehicles        85
# libraries & demo       85
# weather                82
# art & design           65
# events                 64
# parenting              60
# comics                 60
# beauty                 53
# 1.9                     1
# Name: count, dtype: int64

# %%
data['Year']=data['Last Updated'].dt.year

# %%
data
# Out:
#                                                      App           Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       art & design
# 1                                    Coloring book moana       art & design
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       art & design
# 3                                  Sketch - Draw & Paint       art & design
# 4                  Pixel Draw - Number Art Coloring Book       art & design
# ...                                                  ...                ...
# 10836                                   Sya9a Maroc - FR             family
# 10837                   Fr. Mike Schmitz Audio Teachings             family
# 10838                             Parkinson Exercices FR            medical
# 10839                      The SCP Foundation DB fr nn5n  books & reference
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology          lifestyle
#
# ...

# %%
data['Month']=data['Last Updated'].dt.month_name()

# %%
data.head(10)
# Out:
#                                                  App      Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  art & design     4.1
# 1                                Coloring book moana  art & design     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  art & design     4.7
# 3                              Sketch - Draw & Paint  art & design     4.5
# 4              Pixel Draw - Number Art Coloring Book  art & design     4.3
# 5                         Paper flowers instructions  art & design     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  art & design     3.8
# 7                                   Infinite Painter  art & design     4.1
# 8                               Garden Coloring Book  art & design     4.4
# 9                      Kids Paint Free - Drawing Fun  art & design     4.7
#
#     Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159.0  19.0      10,000+  Free    0.0       Everyone
# ...

# %%
data[['Reviews', 'Rating']]=data[['Reviews', 'Rating']].astype('float')

# %%
data.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                  float64
# Size                     float64
# Installs                  object
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# Year                       int32
# Month                     object
# dtype: object

# %%
data
# Out:
#                                                      App           Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       art & design
# 1                                    Coloring book moana       art & design
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       art & design
# 3                                  Sketch - Draw & Paint       art & design
# 4                  Pixel Draw - Number Art Coloring Book       art & design
# ...                                                  ...                ...
# 10836                                   Sya9a Maroc - FR             family
# 10837                   Fr. Mike Schmitz Audio Teachings             family
# 10838                             Parkinson Exercices FR            medical
# 10839                      The SCP Foundation DB fr nn5n  books & reference
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology          lifestyle
#
# ...

# %%
data['Size'].describe()
# Out:
# count    10841.000000
# mean        37.035440
# std         90.810184
# min          1.000000
# 25%          6.800000
# 50%         20.000000
# 75%         37.035440
# max       1020.000000
# Name: Size, dtype: float64

# %%
data['Category']=data['Category'].str.title()

# %%
data
# Out:
#                                                      App           Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       Art & Design
# 1                                    Coloring book moana       Art & Design
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       Art & Design
# 3                                  Sketch - Draw & Paint       Art & Design
# 4                  Pixel Draw - Number Art Coloring Book       Art & Design
# ...                                                  ...                ...
# 10836                                   Sya9a Maroc - FR             Family
# 10837                   Fr. Mike Schmitz Audio Teachings             Family
# 10838                             Parkinson Exercices FR            Medical
# 10839                      The SCP Foundation DB fr nn5n  Books & Reference
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology          Lifestyle
#
# ...

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# Year              0
# Month             0
# dtype: int64

# %%
data['Installs'] = data['Installs'].astype(str)

data['Installs'] = (
    data['Installs']
    .str.replace(',', '', regex=False)
    .str.replace('+', '', regex=False)
)

data['Installs'] = pd.to_numeric(data['Installs'], errors='coerce')

# %%
data
# Out:
#                                                      App           Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       Art & Design
# 1                                    Coloring book moana       Art & Design
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       Art & Design
# 3                                  Sketch - Draw & Paint       Art & Design
# 4                  Pixel Draw - Number Art Coloring Book       Art & Design
# ...                                                  ...                ...
# 10836                                   Sya9a Maroc - FR             Family
# 10837                   Fr. Mike Schmitz Audio Teachings             Family
# 10838                             Parkinson Exercices FR            Medical
# 10839                      The SCP Foundation DB fr nn5n  Books & Reference
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology          Lifestyle
#
# ...

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          1
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# Year              0
# Month             0
# dtype: int64

# %%
data['Installs']=data['Installs'].fillna(data['Installs'].median())

# %%
data['Installs']=data['Installs'].astype('int')

# %%
data.head(15)
# Out:
#                                                   App      Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design     4.1
# 1                                 Coloring book moana  Art & Design     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design     4.7
# 3                               Sketch - Draw & Paint  Art & Design     4.5
# 4               Pixel Draw - Number Art Coloring Book  Art & Design     4.3
# 5                          Paper flowers instructions  Art & Design     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  Art & Design     3.8
# 7                                    Infinite Painter  Art & Design     4.1
# 8                                Garden Coloring Book  Art & Design     4.4
# 9                       Kids Paint Free - Drawing Fun  Art & Design     4.7
# 10                            Text on Photo - Fonteee  Art & Design     4.4
# ...

# %%
data.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                  float64
# Size                     float64
# Installs                   int64
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# Year                       int32
# Month                     object
# dtype: object

# %%
data['Category']=data['Category'].str.replace('1.9', data['Category'].mode()[0])

# %%
data['Category'].unique()
# Out:
# array(['Art & Design', 'Auto & Vehicles', 'Beauty', 'Books & Reference',
#        'Business', 'Comics', 'Communication', 'Dating', 'Education',
#        'Entertainment', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Game', 'Family', 'Medical', 'Social', 'Shopping',
#        'Photography', 'Sports', 'Travel & Local', 'Tools',
#        'Personalization', 'Productivity', 'Parenting', 'Weather',
#        'Video Players', 'News & Magazines', 'Maps & Navigation'],
#       dtype=object)

# %%
data['Category'].value_counts().tail(10)
# Out:
# Category
# Food & Drink        127
# House & Home         88
# Libraries & Demo     85
# Auto & Vehicles      85
# Weather              82
# Art & Design         65
# Events               64
# Comics               60
# Parenting            60
# Beauty               53
# Name: count, dtype: int64

# %%
data.tail(20)
# Out:
#                                                  App           Category  \
# 10821                                        Poop FR             Family
# 10822                                      PLMGSS FR       Productivity
# 10823                                   List iptv FR      Video Players
# 10824                                      Cardio-FR            Medical
# 10825                             Naruto & Boruto FR             Social
# 10826      Frim: get new friends on local chat rooms             Social
# 10827                             Fr Agnel Ambarnath             Family
# 10828                        Manga-FR - Anime Vostfr             Comics
# 10829                 Bulgarian French Dictionary Fr  Books & Reference
# 10830                              News Minecraft.fr   News & Magazines
# 10831                       payermonstationnement.fr  Maps & Navigation
# 10832                                       FR Tides            Weather
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(data['Rating'], bins=8)
plt.xlabel("Rating")
plt.ylabel("Count")
plt.title("Rating Distribution")
plt.show()

# %%
data.sort_values(by='Installs', ascending=False)[['App', 'Installs']].head(10).drop_duplicates(subset='App')
# Out:
#                                            App    Installs
# 5856                         Google Play Games  1000000000
# 5395                             Google Photos  1000000000
# 4170                              Google Drive  1000000000
# 4234             Skype - free IM & video calls  1000000000
# 4104  Messenger – Text and Video Chat for Free  1000000000
# 4144                                   Google+  1000000000
# 4150                                    Google  1000000000
# 4153                                  Hangouts  1000000000

# %%
data.groupby('Category')['Installs'].mean().sort_values(ascending=False)
# Out:
# Category
# Communication        8.435989e+07
# Social               4.769447e+07
# Video Players        3.555430e+07
# Productivity         3.343418e+07
# Game                 3.066960e+07
# Photography          3.011417e+07
# Travel & Local       2.662359e+07
# News & Magazines     2.648876e+07
# Entertainment        1.925611e+07
# Tools                1.358573e+07
# Shopping             1.249173e+07
# Books & Reference    8.318050e+06
# Personalization      5.932385e+06
# Education            5.586231e+06
# Maps & Navigation    5.286729e+06
# Family               5.199373e+06
# Weather              5.196348e+06
# Health & Fitness     4.642441e+06
# Sports               4.560350e+06
# Finance              2.395215e+06
# Business             2.178076e+06
# Food & Drink         2.156683e+06
# House & Home         1.917187e+06
# Art & Design         1.912894e+06
# Lifestyle            1.407444e+06
# Dating               1.129533e+06
# Comics               9.347692e+05
# ...

# %%
data
# Out:
#                                                      App           Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       Art & Design
# 1                                    Coloring book moana       Art & Design
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       Art & Design
# 3                                  Sketch - Draw & Paint       Art & Design
# 4                  Pixel Draw - Number Art Coloring Book       Art & Design
# ...                                                  ...                ...
# 10836                                   Sya9a Maroc - FR             Family
# 10837                   Fr. Mike Schmitz Audio Teachings             Family
# 10838                             Parkinson Exercices FR            Medical
# 10839                      The SCP Foundation DB fr nn5n  Books & Reference
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology          Lifestyle
#
# ...

# %%
data['Type'].unique()
# Out:
# array(['Free', 'Paid', '0'], dtype=object)

# %%
data['Type']=data['Type'].replace(0, np.nan)

# %%
data['Type']=data['Type'].fillna(data['Type'].mode()[0])

# %%
data.groupby('Type')[['Rating', 'Installs']].mean()
# Out:
#         Rating      Installs
# Type
# 0     4.193338  1.000000e+05
# Free  4.186933  1.668929e+07
# Paid  4.252299  9.119510e+04

# %%
data['Type'].value_counts()
# Out:
# Type
# Free    10040
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
import seaborn as sns

corr = data[['Rating', 'Reviews', 'Size', 'Installs', 'Price']].corr()
corr
sns.heatmap(corr, annot=True)
plt.show()

# %%
data.groupby('Content Rating').size().sort_values(ascending=False)
# Out:
# Content Rating
# Everyone           8715
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# dtype: int64

# %%
data['Year'].value_counts()
# Out:
# Year
# 2018    7350
# 2017    1867
# 2016     804
# 2015     459
# 2014     209
# 2013     110
# 2012      26
# 2011      15
# 2010       1
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10, 7))
data.groupby(data['Year'])['Rating'].mean().plot();
