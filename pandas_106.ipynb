# %% [markdown]
# <a href="https://colab.research.google.com/github/malakbayramovaa/pandas-tutorials/blob/main/pandas_106.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

cars = pd.Series(['Bugatti', 'Ferrari','Lambogrhini'])
cars
# Out:
# 0        Bugatti
# 1        Ferrari
# 2    Lambogrhini
# dtype: object

# %%
colors = pd.Series (['Red', 'Blue', 'White'])
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales.csv
# Out:
# --2025-11-29 18:46:53--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2025-11-29 18:46:53 (5.69 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[["Make", "Colour"]]
# Out:
#      Make Colour
# 0  Toyota  White
# 1   Honda    Red
# 2  Toyota   Blue
# 3     BMW  Black
# 4  Nissan  White
# 5  Toyota  Green
# 6   Honda   Blue
# 7   Honda   Blue
# 8  Toyota  White
# 9  Nissan  White

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] >= 90000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00

# %%
car_sales.sum(numeric_only = True)
# Out:
# Odometer (KM)    786014
# Doors                40
# dtype: int64

# %%
car_sales.mean(numeric_only = True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.groupby('Make').mean(numeric_only = True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(['Make', 'Colour'] ).sum(numeric_only = True)
# Out:
#                Odometer (KM)  Doors
# Make   Colour
# BMW    Black           11179      5
# Honda  Blue           100436      8
#        Red             87899      4
# Nissan White          244695      8
# Toyota Blue            32549      3
#        Green           99213      4
#        White          210043      8

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
len(car_sales)
# Out:
# 10

# %%
len(car_sales.columns)
# Out:
# 5

# %%
car_sales['Make'].value_counts()
# Out:
# Make
# Toyota    4
# Honda     3
# Nissan    2
# BMW       1
# Name: count, dtype: int64

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.isna()
# Out:
#     Make  Colour  Odometer (KM)  Doors  Price
# 0  False   False          False  False  False
# 1  False   False          False  False  False
# 2  False   False          False  False  False
# 3  False   False          False  False  False
# 4  False   False          False  False  False
# 5  False   False          False  False  False
# 6  False   False          False  False  False
# 7  False   False          False  False  False
# 8  False   False          False  False  False
# 9  False   False          False  False  False

# %%
car_sales.isna().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
car_sales['Odometer Mile'] = car_sales['Odometer (KM)'] / 1.6
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer Mile
# 0  Toyota  White         150043      4   $4,000.00      93776.875
# 1   Honda    Red          87899      4   $5,000.00      54936.875
# 2  Toyota   Blue          32549      3   $7,000.00      20343.125
# 3     BMW  Black          11179      5  $22,000.00       6986.875
# 4  Nissan  White         213095      4   $3,500.00     133184.375
# 5  Toyota  Green          99213      4   $4,500.00      62008.125
# 6   Honda   Blue          45698      4   $7,500.00      28561.250
# 7   Honda   Blue          54738      4   $7,000.00      34211.250
# 8  Toyota  White          60000      4   $6,250.00      37500.000
# 9  Nissan  White          31600      4   $9,700.00      19750.000

# %%
car_sales['Currency'] = "USD"
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer Mile Currency
# 0  Toyota  White         150043      4   $4,000.00      93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00      54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00      20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00       6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00     133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00      62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00      28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00      34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00      37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00      19750.000      USD

# %%
car_sales.rename({'Odometer Mile ' : 'Odometer (Mile) '} , axis = 1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer Mile Currency
# 0  Toyota  White         150043      4   $4,000.00      93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00      54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00      20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00       6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00     133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00      62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00      28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00      34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00      37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00      19750.000      USD

# %%
car_sales.drop({'Odometer Mile' }, axis = 1, inplace = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Currency
# 0  Toyota  White         150043      4   $4,000.00      USD
# 1   Honda    Red          87899      4   $5,000.00      USD
# 2  Toyota   Blue          32549      3   $7,000.00      USD
# 3     BMW  Black          11179      5  $22,000.00      USD
# 4  Nissan  White         213095      4   $3,500.00      USD
# 5  Toyota  Green          99213      4   $4,500.00      USD
# 6   Honda   Blue          45698      4   $7,500.00      USD
# 7   Honda   Blue          54738      4   $7,000.00      USD
# 8  Toyota  White          60000      4   $6,250.00      USD
# 9  Nissan  White          31600      4   $9,700.00      USD

# %%
car_sales['Odometer (Mile)'] = car_sales['Odometer (KM)'].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Currency  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00      USD        93776.875
# 1   Honda    Red          87899      4   $5,000.00      USD        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00      USD        20343.125
# 3     BMW  Black          11179      5  $22,000.00      USD         6986.875
# 4  Nissan  White         213095      4   $3,500.00      USD       133184.375
# 5  Toyota  Green          99213      4   $4,500.00      USD        62008.125
# 6   Honda   Blue          45698      4   $7,500.00      USD        28561.250
# 7   Honda   Blue          54738      4   $7,000.00      USD        34211.250
# 8  Toyota  White          60000      4   $6,250.00      USD        37500.000
# 9  Nissan  White          31600      4   $9,700.00      USD        19750.000

# %%
car_sales.drop({'Currency' }, axis = 1, inplace = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
def currency (x):
  if "$" in x :
    return "USD"
  elif "€" in x:
    return "Euro"
  else :
    return "Unknown"

car_sales['Currency'] = car_sales['Price'].apply(currency)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
car_sales[car_sales["Odometer (Mile)"] > 100_000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer (Mile) Currency
# 4  Nissan  White         213095      4  $3,500.00       133184.375      USD

# %%
car_sales.drop(1)  # 1 ci sutunu silir
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
car_sales[['Make', 'Colour']]
# Out:
#      Make Colour
# 0  Toyota  White
# 1   Honda    Red
# 2  Toyota   Blue
# 3     BMW  Black
# 4  Nissan  White
# 5  Toyota  Green
# 6   Honda   Blue
# 7   Honda   Blue
# 8  Toyota  White
# 9  Nissan  White

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.drop(car_sales[car_sales["Odometer (Mile)"] > 100_000].index)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
car_sales.drop(car_sales[car_sales["Colour"] == "Blue"].index)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
car_sales[car_sales['Colour'] != 'Blue']
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
car_sales[(car_sales['Colour'] != 'Blue') | (car_sales['Odometer (KM)'] > 100_000)]
# & and demekdir, | or demekdir.
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
car_sales[(car_sales['Colour'] == 'Blue') | (car_sales['Odometer (KM)'] > 100_000) & (car_sales['Make'] == "Nissan")]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer (Mile) Currency
# 2  Toyota   Blue          32549      3  $7,000.00        20343.125      USD
# 4  Nissan  White         213095      4  $3,500.00       133184.375      USD
# 6   Honda   Blue          45698      4  $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4  $7,000.00        34211.250      USD

# %%
car_sales[(car_sales['Colour'] == "White" ) & (car_sales['Make'] == "Toyota") |  (car_sales ['Odometer (KM)'] < 50_000)]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
car_sales.loc[[1, 5]] # 1 ve 5 ci rowu gosterir
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer (Mile) Currency
# 1   Honda    Red          87899      4  $5,000.00        54936.875      USD
# 5  Toyota  Green          99213      4  $4,500.00        62008.125      USD

# %%
animals = pd.Series(['cat', 'dog', 'bird', 'panda', 'snake'] , index = [0,3,9,8,3])  # Series - one dimensional data
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3] # indeksi 3 olanlari qaytarir
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[3] #sadece sira nomresine gore baxir bizim yazdigimiz indekse baxmir.
# Out:
# 'panda'

# %%
car_sales.sort_values(by = 'Odometer (KM)') # Odometer (KM) olan hisseni kicikden boyuye siralayir.
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD

# %%
car_sales.sort_values(by = 'Odometer (KM)', ascending = False)  # Odometer (KM) boyukden kiciye siralayir.
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD

# %%
car_sales.sample(frac=1)  #qarisdirir, yerlerini deyisir   frac -> fraction  frac = 1 hamisini qarisdirir, 0.2 - 20 faizini qarisdirir
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD

# %%
car_sales.dtypes
# Out:
# Make                object
# Colour              object
# Odometer (KM)        int64
# Doors                int64
# Price               object
# Odometer (Mile)    float64
# Currency            object
# dtype: object

# %%
'heyyy'.replace("h", ' k') # h herfi ile k herfinin yerini deyisdirir.
# Out:
# ' keyyy'

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex = True).astype(int)
car_sales
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-1782244142.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex = True).astype(int)
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   400000        93776.875      USD
# 1   Honda    Red          87899      4   500000        54936.875      USD
# 2  Toyota   Blue          32549      3   700000        20343.125      USD
# 3     BMW  Black          11179      5  2200000         6986.875      USD
# 4  Nissan  White         213095      4   350000       133184.375      USD
# 5  Toyota  Green          99213      4   450000        62008.125      USD
# 6   Honda   Blue          45698      4   750000        28561.250      USD
# 7   Honda   Blue          54738      4   700000        34211.250      USD
# ...

# %%
car_sales['Price'].dtype
# Out:
# dtype('int64')

# %%
car_sales['Price'] = car_sales['Price'] / 100
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875      USD
# 1   Honda    Red          87899      4   5000.0        54936.875      USD
# 2  Toyota   Blue          32549      3   7000.0        20343.125      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 4  Nissan  White         213095      4   3500.0       133184.375      USD
# 5  Toyota  Green          99213      4   4500.0        62008.125      USD
# 6   Honda   Blue          45698      4   7500.0        28561.250      USD
# 7   Honda   Blue          54738      4   7000.0        34211.250      USD
# 8  Toyota  White          60000      4   6250.0        37500.000      USD
# 9  Nissan  White          31600      4   9700.0        19750.000      USD

# %%
! wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales-missing-data.csv
# Out:
# --2025-11-29 18:46:55--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales-missing-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘car-sales-missing-data.csv’
#
# car-sales-missing-d 100%[===================>]     287  --.-KB/s    in 0s
#
# 2025-11-29 18:46:55 (5.97 MB/s) - ‘car-sales-missing-data.csv’ saved [287/287]

# %%
car_sales_missing = pd.read_csv('/content/car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
! wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/pandas-exercises.ipynb
# Out:
# --2025-11-29 18:46:55--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/pandas-exercises.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14082 (14K) [text/plain]
# Saving to: ‘pandas-exercises.ipynb’
#
# pandas-exercises.ip 100%[===================>]  13.75K  --.-KB/s    in 0.002s
#
# 2025-11-29 18:46:55 (6.58 MB/s) - ‘pandas-exercises.ipynb’ saved [14082/14082]

# %%
car_sales[car_sales['Colour'] == 'Blue']
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Odometer (Mile) Currency
# 2  Toyota   Blue          32549      3  7000.0        20343.125      USD
# 6   Honda   Blue          45698      4  7500.0        28561.250      USD
# 7   Honda   Blue          54738      4  7000.0        34211.250      USD

# %%
car_sales[(car_sales['Colour'] == 'Blue') | (car_sales['Price'] > 8_000)]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 2  Toyota   Blue          32549      3   7000.0        20343.125      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 6   Honda   Blue          45698      4   7500.0        28561.250      USD
# 7   Honda   Blue          54738      4   7000.0        34211.250      USD
# 9  Nissan  White          31600      4   9700.0        19750.000      USD

# %%
car_sales.drop('Doors', axis = 1)
# Out:
#      Make Colour  Odometer (KM)    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043   4000.0        93776.875      USD
# 1   Honda    Red          87899   5000.0        54936.875      USD
# 2  Toyota   Blue          32549   7000.0        20343.125      USD
# 3     BMW  Black          11179  22000.0         6986.875      USD
# 4  Nissan  White         213095   3500.0       133184.375      USD
# 5  Toyota  Green          99213   4500.0        62008.125      USD
# 6   Honda   Blue          45698   7500.0        28561.250      USD
# 7   Honda   Blue          54738   7000.0        34211.250      USD
# 8  Toyota  White          60000   6250.0        37500.000      USD
# 9  Nissan  White          31600   9700.0        19750.000      USD

# %%
car_sales.drop(9)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875      USD
# 1   Honda    Red          87899      4   5000.0        54936.875      USD
# 2  Toyota   Blue          32549      3   7000.0        20343.125      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 4  Nissan  White         213095      4   3500.0       133184.375      USD
# 5  Toyota  Green          99213      4   4500.0        62008.125      USD
# 6   Honda   Blue          45698      4   7500.0        28561.250      USD
# 7   Honda   Blue          54738      4   7000.0        34211.250      USD
# 8  Toyota  White          60000      4   6250.0        37500.000      USD

# %%
car_sales.drop_duplicates()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875      USD
# 1   Honda    Red          87899      4   5000.0        54936.875      USD
# 2  Toyota   Blue          32549      3   7000.0        20343.125      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 4  Nissan  White         213095      4   3500.0       133184.375      USD
# 5  Toyota  Green          99213      4   4500.0        62008.125      USD
# 6   Honda   Blue          45698      4   7500.0        28561.250      USD
# 7   Honda   Blue          54738      4   7000.0        34211.250      USD
# 8  Toyota  White          60000      4   6250.0        37500.000      USD
# 9  Nissan  White          31600      4   9700.0        19750.000      USD

# %%
car_sales.drop_duplicates(subset = ['Make'])  # make sutunu uzerinde fergli olanlari qaytarir
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875      USD
# 1   Honda    Red          87899      4   5000.0        54936.875      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 4  Nissan  White         213095      4   3500.0       133184.375      USD

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875      USD
# 1   Honda    Red          87899      4   5000.0        54936.875      USD
# 2  Toyota   Blue          32549      3   7000.0        20343.125      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 4  Nissan  White         213095      4   3500.0       133184.375      USD
# 5  Toyota  Green          99213      4   4500.0        62008.125      USD
# 6   Honda   Blue          45698      4   7500.0        28561.250      USD
# 7   Honda   Blue          54738      4   7000.0        34211.250      USD
# 8  Toyota  White          60000      4   6250.0        37500.000      USD
# 9  Nissan  White          31600      4   9700.0        19750.000      USD

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isna().sum() #
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
car_sales_missing.dropna() # butun setirleri silir hansinin ki icinde null qiymetler var.
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing.dropna(subset = ['Price'])
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales['Make'].fillna('Missing', inplace = True)  # null qiymetlerin yerini missing sozu ile doldurur
car_sales_missing
# Out:
# /tmp/ipython-input-1360881088.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales['Make'].fillna('Missing', inplace = True)  # null qiymetlerin yerini missing sozu ile doldurur
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# ...

# %%
car_sales_missing['Colour'].mode()[0]  # en cox tekrarlanan qiymetleri qaytarir
# Out:
# 'White'

# %%
car_sales_missing['Colour'].fillna(car_sales_missing['Colour'].mode() [0],inplace = True )
car_sales_missing
# Out:
# /tmp/ipython-input-2032364297.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing['Colour'].fillna(car_sales_missing['Colour'].mode() [0],inplace = True )
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# ...

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean() , inplace = True)
car_sales_missing
# Out:
# /tmp/ipython-input-2070491509.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean() , inplace = True)
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# ...

# %%
car_sales.to_csv("my amazing analysis")

# %%
car_sales.to_excel("my amazing analysis.xlsx")

# %%
pd.concat([car_sales, car_sales_missing] )  #birlesdirir
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency  \
# 0  Toyota  White       150043.0    4.0   4000.0        93776.875      USD
# 1   Honda    Red        87899.0    4.0   5000.0        54936.875      USD
# 2  Toyota   Blue        32549.0    3.0   7000.0        20343.125      USD
# 3     BMW  Black        11179.0    5.0  22000.0         6986.875      USD
# 4  Nissan  White       213095.0    4.0   3500.0       133184.375      USD
# 5  Toyota  Green        99213.0    4.0   4500.0        62008.125      USD
# 6   Honda   Blue        45698.0    4.0   7500.0        28561.250      USD
# 7   Honda   Blue        54738.0    4.0   7000.0        34211.250      USD
# 8  Toyota  White        60000.0    4.0   6250.0        37500.000      USD
# 9  Nissan  White        31600.0    4.0   9700.0        19750.000      USD
# 0  Toyota  White            NaN    4.0   $4,000              NaN      NaN
# 1   Honda    Red            NaN    4.0   $5,000              NaN      NaN
# ...

# %%
df1 = pd.DataFrame({'A' : [1,2,3], 'B': [4,5,6]})
df2 = pd.DataFrame({'AA': [1,2,3], 'C' : [10,11,12]})
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
pd.concat([df1,df2])
# Out:
#      A    B   AA     C
# 0  1.0  4.0  NaN   NaN
# 1  2.0  5.0  NaN   NaN
# 2  3.0  6.0  NaN   NaN
# 0  NaN  NaN  1.0  10.0
# 1  NaN  NaN  2.0  11.0
# 2  NaN  NaN  3.0  12.0

# %%
pd.merge(df1, df2, left_on = "A", right_on = "AA", how = 'left')
# Out:
#    A  B  AA   C
# 0  1  4   1  10
# 1  2  5   2  11
# 2  3  6   3  12

# %%
pd.crosstab(car_sales['Make'], car_sales['Colour'])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
import pandas as pd
data = [[8], [8], [3], [3], [1], [4], [5], [6]]
my_numbers = pd.DataFrame(data, columns=['num']).astype({'num':'Int64'})
my_numbers
counts = my_numbers.value_counts().reset_index()
single_numbers = counts[counts['count'] == 1]
pd.DataFrame({'num' : [max(single_numbers['num'])]})
# Out:
#    num
# 0    6
