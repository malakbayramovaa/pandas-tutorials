# %% [markdown]
# <a href="https://colab.research.google.com/github/malakbayramovaa/pandas-tutorials/blob/main/cirrhosis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * **ID** - Xəstənin unikal identifikatoru
# * **N_Days** - Xəstənin izlənildiyi gün sayı
# * **Status** - Xəstənin son vəziyyəti
# * **Drug** - Müalicə növü
# * **Age** - Xəstənin yaşı günlərlə
# * **Sex** - Xəstənin cinsi
# * **Ascites** - Qarın boşluğunda maye yığılması
# * **Hepatomegaly** - Qaraciyərin böyüməsi
# * **Spiders** - Dəridə damar genişlənməsi
# * **Edema** - Şişkinlik səviyyəsi
# * **Bilirubin** - Qanda bilirubin səviyyəsi
# * **Cholesterol** - Xolesterin səviyyəsi
# * **Albumin** - Qanda albumin miqdarı
# * **Alk_Phos** - Qaraciyər və sümük göstəricisi
# * **SGOT** - Qaraciyər zədəsinin göstəricisi
# * **Tryglicerides** - Trigliserid səviyyəsi
# * **Platelets** - Trombosit sayı
# * **Prothrombin** - Qanın laxtalanma vaxtı
#  * **Stage** - Sirrozun mərhələsi

# %%
import pandas as pd
df=pd.read_csv('/content/cirrhosis.csv')
df
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df.head(5)
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
# ...

# %%
df.describe()
# Out:
#                ID       N_Days           Age   Bilirubin  Cholesterol  \
# count  418.000000   418.000000    418.000000  418.000000   284.000000
# mean   209.500000  1917.782297  18533.351675    3.220813   369.510563
# std    120.810458  1104.672992   3815.845055    4.407506   231.944545
# min      1.000000    41.000000   9598.000000    0.300000   120.000000
# 25%    105.250000  1092.750000  15644.500000    0.800000   249.500000
# 50%    209.500000  1730.000000  18628.000000    1.400000   309.500000
# 75%    313.750000  2613.500000  21272.500000    3.400000   400.000000
# max    418.000000  4795.000000  28650.000000   28.000000  1775.000000
#
#           Albumin      Copper      Alk_Phos        SGOT  Tryglicerides  \
# count  418.000000  310.000000    312.000000  312.000000     282.000000
# mean     3.497440   97.648387   1982.655769  122.556346     124.702128
# std      0.424972   85.613920   2140.388824   56.699525      65.148639
# ...

# %%
df.columns
# Out:
# Index(['ID', 'N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites',
#        'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
#        'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
#        'Prothrombin', 'Stage'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
df['age'] = (df['Age'] / 365).round()
df['age']
# Out:
# 0      59.0
# 1      56.0
# 2      70.0
# 3      55.0
# 4      38.0
#        ...
# 413    67.0
# 414    39.0
# 415    57.0
# 416    58.0
# 417    53.0
# Name: age, Length: 418, dtype: float64

# %%
df=df.drop(columns=['Age', 'ID'], axis=True)

# %%
df
# Out:
#      N_Days Status             Drug Sex Ascites Hepatomegaly Spiders Edema  \
# 0       400      D  D-penicillamine   F       Y            Y       Y     Y
# 1      4500      C  D-penicillamine   F       N            Y       Y     N
# 2      1012      D  D-penicillamine   M       N            N       N     S
# 3      1925      D  D-penicillamine   F       N            Y       Y     S
# 4      1504     CL          Placebo   F       N            Y       Y     N
# ..      ...    ...              ...  ..     ...          ...     ...   ...
# 413     681      D              NaN   F     NaN          NaN     NaN     N
# 414    1103      C              NaN   F     NaN          NaN     NaN     N
# 415    1055      C              NaN   F     NaN          NaN     NaN     N
# 416     691      C              NaN   F     NaN          NaN     NaN     N
# 417     976      C              NaN   F     NaN          NaN     NaN     N
#
# ...

# %%
df['age']=df['age'].astype('int')

# %%
df.dtypes
# Out:
# N_Days             int64
# Status            object
# Drug              object
# Sex               object
# Ascites           object
# Hepatomegaly      object
# Spiders           object
# Edema             object
# Bilirubin        float64
# Cholesterol      float64
# Albumin          float64
# Copper           float64
# Alk_Phos         float64
# SGOT             float64
# Tryglicerides    float64
# Platelets        float64
# Prothrombin      float64
# Stage            float64
# age                int64
# dtype: object

# %%
df
# Out:
#      N_Days Status             Drug Sex Ascites Hepatomegaly Spiders Edema  \
# 0       400      D  D-penicillamine   F       Y            Y       Y     Y
# 1      4500      C  D-penicillamine   F       N            Y       Y     N
# 2      1012      D  D-penicillamine   M       N            N       N     S
# 3      1925      D  D-penicillamine   F       N            Y       Y     S
# 4      1504     CL          Placebo   F       N            Y       Y     N
# ..      ...    ...              ...  ..     ...          ...     ...   ...
# 413     681      D              NaN   F     NaN          NaN     NaN     N
# 414    1103      C              NaN   F     NaN          NaN     NaN     N
# 415    1055      C              NaN   F     NaN          NaN     NaN     N
# 416     691      C              NaN   F     NaN          NaN     NaN     N
# 417     976      C              NaN   F     NaN          NaN     NaN     N
#
# ...

# %%
df['Stage'] = df['Stage'].fillna(df['Stage'].median()).astype(int)

# %%
# numeric_cols = df.select_dtypes(include='number').columns
# print("Numeric columns:", numeric_cols)
# print('\t')
# IQR metodu ilə outlier tapmaq
# outlier_dict = {}
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Outlier-ları tap
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
    # outlier_dict[col] = outliers
    print(f"{col} - Outliers count: {len(outliers)}")
# Out:
# N_Days - Outliers count: 0
# Bilirubin - Outliers count: 46
# Cholesterol - Outliers count: 51
# Albumin - Outliers count: 9
# Copper - Outliers count: 45
# Alk_Phos - Outliers count: 45
# SGOT - Outliers count: 26
# Tryglicerides - Outliers count: 47
# Platelets - Outliers count: 6
# Prothrombin - Outliers count: 18
# Stage - Outliers count: 0
# age - Outliers count: 0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Status-un paylanması
print(df['Status'].value_counts())

# Vizual
sns.countplot(x='Status', data=df)
plt.title("Distribution of Status")
plt.show()
# Out:
# Status
# C     232
# D     161
# CL     25
# Name: count, dtype: int64

# %%
stage_status = df.groupby('Stage')['Status'].value_counts(normalize=True).unstack()
print(stage_status)
# Out:
# Status         C        CL         D
# Stage
# 1       0.904762       NaN  0.095238
# 2       0.695652  0.054348  0.250000
# 3       0.614907  0.062112  0.322981
# 4       0.347222  0.069444  0.583333

# %%
stage_numeric = df.groupby('Stage')[numeric_cols].mean()
print(stage_numeric)
# Out:
#             N_Days  Bilirubin  Cholesterol   Albumin      Copper     Alk_Phos  \
# Stage
# 1      2654.809524   1.361905   267.846154  3.705238   62.812500  1694.212500
# 2      2389.836957   2.453261   353.180328  3.607065   68.030303  1816.907463
# 3      1996.900621   2.822981   415.852174  3.582112   92.075000  2082.128333
# 4      1420.250000   4.427083   337.810526  3.302431  127.101852  2017.366972
#
#              SGOT  Tryglicerides   Platelets  Prothrombin  Stage        age
# Stage
# 1       84.460000      90.846154  291.800000    10.780000    1.0  47.000000
# 2      115.562388     113.950820  286.895349    10.525000    2.0  49.478261
# 3      124.326750     130.734513  265.213836    10.474534    3.0  49.285714
# 4      130.498440     129.063158  224.866197    11.147552    4.0  53.812500

# %%
pivot_drug = pd.pivot_table(df, values='SGOT', index='Drug', columns='Status', aggfunc='median')
print(pivot_drug)
# Out:
# Status               C     CL        D
# Drug
# D-penicillamine  91.00  129.1  130.200
# Placebo          97.65  117.0  137.175

# %%
sns.histplot(df['Bilirubin'],kde=True)
# Out:
# <Axes: xlabel='Bilirubin', ylabel='Count'>

# %%
sns.heatmap(df[numeric_cols].corr(), annot=True)
# Out:
# <Axes: >

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F    374
# M     44
# dtype: int64

# %%
categorical = df.select_dtypes(include=['object']).columns
categorical
# Out:
# Index(['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema'], dtype='object')

# %%
numeric_cols
# Out:
# Index(['N_Days', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper', 'Alk_Phos',
#        'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin', 'Stage', 'age'],
#       dtype='object')

# %%
for col in categorical:
  df[col] = df[col].fillna(df[col].mode()[0])

# %%
for col in numeric_cols:
  df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# N_Days           0
# Status           0
# Drug             0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# age              0
# dtype: int64
